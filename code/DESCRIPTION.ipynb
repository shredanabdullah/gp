# %%
descriptions = [
    "Welcome to Our Animal Sanctuary Website: Step into our digital zoo where nature's wonders come alive with every click.",
    "Embrace the Beauty of Wild Creatures on Our Nature Website: Explore our green-themed website dedicated to celebrating the diversity of animals in their natural habitats.",
    "Journey Through Nature's Playground on Our Wildlife Website: Navigate through lush greenery and discover the untamed beauty of wildlife across the globe.",
    "Discover the Charm of Zoo Life on Our Animal Website: Immerse yourself in the captivating world of zoo animals and their unique behaviors.",
    "Connect with Wildlife Through Our Zoo Website: Engage with our community of animal enthusiasts and conservation advocates passionate about protecting nature.",
    "Explore the Depths of Wildlife on Our Animal Website: Dive deep into our digital exploration of animal species, from the majestic to the endangered.",
    "Celebrate Nature's Diversity on Our Wildlife Website: Delve into the kaleidoscope of animal life thriving in our green-themed virtual sanctuary.",
    "Learn About Zoo Habitats on Our Nature Website: Journey through different zoo habitats and learn about the animals that call them home.",
    "Wildlife Conservation Insights on Our Animal Website: Gain insights into wildlife conservation efforts and how you can contribute to protecting animals and their habitats.",
    "Experience the Magic of Zoo Encounters on Our Wildlife Website: Take a virtual tour through our interactive zoo encounters, where every animal has a story to tell.",
    "Explore Wildlife in its Natural Setting on Our Animal Website: Navigate through our nature-inspired website and uncover the beauty of animals in the wild.",
    "Educational Adventures in Nature on Our Zoo Website: Embark on educational adventures that showcase the wonders of zoo life and animal behavior.",
    "Discover Animal Species on Our Wildlife Website: Explore our comprehensive guide to animal species, from the iconic to the lesser-known creatures.",
    "Wildlife Preservation on Our Animal Website: Learn about our commitment to wildlife preservation and the role of zoos in conservation efforts.",
    "Zoo-inspired Conservation on Our Nature Website: Dive into our zoo-inspired conservation initiatives aimed at protecting endangered species and their habitats.",
    "Green Sanctuary for Animals on Our Wildlife Website: Join us in our mission to create a green sanctuary where animals thrive and nature is preserved.",
    "Interactive Zoo Experiences on Our Animal Website: Engage in interactive zoo experiences that bring you up close to the sights and sounds of the animal kingdom.",
    "Animal Welfare and Care on Our Zoo Website: Discover our dedication to animal welfare and care, ensuring every creature in our digital zoo receives the best.",
    "Virtual Wildlife Safari on Our Nature Website: Embark on a virtual wildlife safari through our green-themed website, exploring the wonders of the animal kingdom.",
    "Zoo Conservation Network on Our Wildlife Website: Connect with our global zoo conservation network dedicated to safeguarding animals and their habitats for future generations."
]

car_descriptions = [
    "Explore Our Website for Reliable Cars and Car Repairs: Discover a wide selection of quality cars and expert car repair services to keep your vehicle running smoothly.",
    "Expert Car Repair Services: Trust our skilled technicians for comprehensive car repairs, from routine maintenance to complex engine diagnostics and repairs.",
    "Find Your Dream Car: Browse our website for a diverse inventory of new and used cars, offering options to suit every budget and preference.",
    "Scheduled Maintenance for Optimal Performance: Keep your car in top condition with our scheduled maintenance services, ensuring reliability and longevity.",
    "Quality Parts and Accessories: Enhance your driving experience with our range of quality car parts and accessories, available for purchase on our website.",
    "Emergency Roadside Assistance: Count on us for prompt roadside assistance services, available 24/7 to handle emergencies and breakdowns.",
    "Specialized Engine Tuning: Improve your car's performance with our specialized engine tuning services, optimizing power and fuel efficiency.",
    "Tire Sales and Services: Choose from a variety of tires for all seasons and road conditions, with professional installation and balancing services available.",
    "Brake System Inspections and Repairs: Ensure safety with regular brake system inspections and expert repairs, preventing potential brake failures.",
    "Transmission Repair and Maintenance: Trust our experts for reliable transmission repair and maintenance services, ensuring smooth shifting and performance.",
    "Diagnostic Services: Diagnose and resolve car issues with our advanced diagnostic services, using state-of-the-art equipment for accurate results.",
    "Bodywork and Collision Repair: Restore your car's appearance and structural integrity with our professional bodywork and collision repair services.",
    "Exhaust System Services: Maintain optimal engine performance and reduce emissions with our exhaust system inspections and repairs.",
    "Air Conditioning Services: Stay cool and comfortable with our air conditioning services, including diagnostics, repairs, and recharging of refrigerant.",
    "Wheel Alignment and Balancing: Enhance handling and extend tire life with our wheel alignment and balancing services, ensuring even tire wear.",
    "Fuel System Maintenance: Improve fuel efficiency and engine performance with our fuel system maintenance and cleaning services.",
    "Electrical System Diagnostics: Resolve electrical issues with our thorough electrical system diagnostics and repairs, ensuring reliable operation.",
    "Interior and Exterior Detailing: Restore your car's shine and cleanliness with our comprehensive interior and exterior detailing services.",
    "Customization and Upgrades: Personalize your car with our customization and upgrade services, enhancing both aesthetics and performance.",
    "Pre-Purchase Inspections: Make an informed decision with our pre-purchase inspections, providing detailed evaluations of used cars before buying."
]

charity_descriptions = [
    "Support Our Cause on Our Charity Website: Join us in making a difference through our dedicated charity efforts, where every donation counts towards changing lives.",
    "Donate to Make an Impact: Your support on our charity website helps us provide essential services to those in need, ensuring a brighter future for all.",
    "Volunteer and Change Lives: Get involved with our charity's volunteer programs, where your time and skills make a meaningful difference in the community.",
    "Empower Communities Through Education: Join our mission on our charity website to empower communities through educational initiatives and opportunities.",
    "Transform Lives Through Health Initiatives: Your donations on our charity website enable us to deliver life-saving healthcare services to underserved populations.",
    "Protect the Environment Together: Join our environmental conservation efforts on our charity website, where your actions contribute to a sustainable future.",
    "Foster Animal Welfare: Support our animal welfare programs on our charity website, advocating for the rights and well-being of animals in need.",
    "Promote Arts and Culture: Donate to our charity's arts and culture initiatives on our website, preserving heritage and fostering creativity in our communities.",
    "Provide Shelter and Hope: Your contributions on our charity website provide shelter and hope to homeless individuals and families seeking refuge.",
    "Combat Hunger and Food Insecurity: Join us in the fight against hunger by donating on our charity website, ensuring no one goes to bed hungry.",
    "Empower Women and Girls: Support our gender equality programs on our charity website, empowering women and girls to reach their full potential.",
    "Build Sustainable Communities: Your donations on our charity website help us build sustainable communities through infrastructure and development projects.",
    "Support Mental Health Initiatives: Donate to our mental health programs on our charity website, promoting awareness and providing support to those in need.",
    "Respond to Humanitarian Crises: Join our emergency relief efforts on our charity website, providing aid to communities affected by natural disasters and conflicts.",
    "Advocate for Social Justice: Support our advocacy campaigns on our charity website, promoting social justice and equality for all individuals.",
    "Educate and Empower Youth: Invest in the future by donating to our youth education programs on our charity website, empowering the next generation.",
    "Promote Sustainable Development Goals: Join our commitment to achieving the UN Sustainable Development Goals on our charity website.",
    "Support Local Communities: Your donations on our charity website directly support local community projects, strengthening social bonds and resilience.",
    "Create Access to Clean Water: Donate to our clean water initiatives on our charity website, providing access to safe and clean drinking water for communities in need.",
    "Build a Better Future Together: Get involved with our charity's initiatives on our website, where collective action creates positive change for a better world."
]

beauty_descriptions = [
    "Pamper Yourself with Our Luxurious Spa Treatments: Indulge in a relaxing retreat at our beauty salon, offering a range of spa services to rejuvenate your body and mind.",
    "Discover the Art of Hair Styling: Transform your look with our expert hair stylists who specialize in trendy cuts, vibrant colors, and personalized treatments.",
    "Revitalize Your Skin with Professional Facials: Experience the ultimate glow-up with our rejuvenating facials designed to cleanse, exfoliate, and hydrate your skin.",
    "Nail Care Excellence: Treat yourself to a flawless manicure and pedicure session, featuring the latest nail art trends and premium nail care products.",
    "Unwind with Therapeutic Massages: Escape the stress of daily life with our therapeutic massage therapies, tailored to relieve tension and promote relaxation.",
    "Eyelash Extensions for Effortless Glamour: Enhance your natural beauty with our eyelash extension services, creating voluminous lashes that wow.",
    "Expert Makeup Artistry: Achieve your desired look with our professional makeup artists, specializing in bridal, evening, and editorial makeup.",
    "Gentle Waxing Services: Smooth and silky skin awaits with our gentle waxing services, ensuring a comfortable experience and long-lasting results.",
    "Brow Shaping and Tinting: Frame your face with perfectly shaped brows and add definition with our brow tinting services for a polished look.",
    "Skin Care Solutions: Address your skin concerns with our customized skin care treatments, designed to nourish, rejuvenate, and maintain skin health.",
    "Body Contouring and Slimming Treatments: Sculpt your body with our non-invasive body contouring treatments, targeting stubborn areas for a toned appearance.",
    "Special Occasion Styling: Look your best for any special event with our expert styling services, creating elegant updos and glamorous hair designs.",
    "Men's Grooming Essentials: Enhance your grooming routine with our tailored services for men, including haircuts, beard trims, and skincare treatments.",
    "HydraFacial Treatments: Reveal radiant skin with our HydraFacial treatments, combining deep cleansing, exfoliation, extraction, hydration, and antioxidant protection.",
    "Permanent Makeup Solutions: Wake up with makeup with our semi-permanent makeup solutions, including microblading, lip blush, and eyeliner tattooing.",
    "Hair Extensions for Volume and Length: Transform your hair with our premium hair extension services, offering natural-looking volume and length.",
    "Spray Tanning for a Sun-Kissed Glow: Achieve a flawless tan without UV exposure with our professional spray tanning services, tailored to your skin tone.",
    "Microdermabrasion for Skin Renewal: Renew and refine your skin's texture with our microdermabrasion treatments, promoting smoother and brighter complexion.",
    "Luxury Spa Packages: Treat yourself or a loved one to our exclusive spa packages, combining multiple treatments for a day of pampering and relaxation.",
    "Bridal Beauty Services: Prepare for your special day with our bridal beauty services, including bridal hair, makeup trials, and bridal party styling."
]

directory = "C:\\Users\\Tobi\\Desktop\\beauty\\desc\\"

for idx, desc in enumerate(beauty_descriptions):
    filename = f"{idx}.txt"
    with open(directory + filename, "w") as file:
        file.write(desc)
print("Text files created successfully.")
# Out:
# Text files created successfully.
